# %% [markdown]
# <a href="https://colab.research.google.com/github/Vikasini2406/pp-III/blob/main/Lab_ex1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
principal=float(input("Enter the principal amount(Rupees):"))
rate=float(input("Enter the rate of interest(%):"))
time=float(input("Enter the time (years):"))
interest=(principal*rate*time)/100
print("The interest on the loan is:",interest)
# Out:
# Enter the principal amount(Rupees):7800
# Enter the rate of interest(%):7.7
# Enter the time (years):26
# The interest on the loan is: 15615.6

# %%
a = int(input("Enter a: "))
b = int(input("Enter b: "))
cal = input("Enter operation (+ - * /): ")

match cal:
    case '+':
        print(a + b)
    case '-':
        print(a - b)
    case '*':
        print(a * b)
    case '/':
        print(a / b)
    case _:
        print("Invalid operation")

# %%
a=int(input("enter age: "))
if(a>18):
  print("eligible for voting")
else:
  print("not eligible for voting")
# Out:
# enter age: 30
# eligible for voting

# %%
for i in range(5,0,-1):
  print(i*"*")
# Out:
# *****
# ****
# ***
# **
# *

# %%
print("Menu-Driven Calculator")
print("1.Addition")
print("2.Subtraction")
print("3.Multiplication")
print("4.Division")
a=float(input("Enter first number:"))
b=float(input("Enter second number:"))
choice=int(input("Enter your choice:"))
match choice:
 case 1:
  print("Result:",a+b)
 case 2:
  print("Result:",a-b)
 case 3:
  print("Result:",a*b)
 case 4:
  print("Result:",a/b)
# Out:
# Menu-Driven Calculator
# 1.Addition
# 2.Subtraction
# 3.Multiplication
# 4.Division
# Enter first number:20
# Enter second number:10
# Enter your choice:4
# Result: 2.0
