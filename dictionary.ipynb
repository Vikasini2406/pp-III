# %% [markdown]
# <a href="https://colab.research.google.com/github/Vikasini2406/pp-III/blob/main/dictionary.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
Employee={"name":"vikasini","age":19,"salary":10000}
print(type(Employee))
print("printing employee data")
print(Employee)
# Out:
# <class 'dict'>
# printing employee data
# {'name': 'vikasini', 'age': 19, 'salary': 10000}

# %%
Dict=dict({1:'apple',2:'orange',3:'banana'})
print(Dict)
# Out:
# {1: 'apple', 2: 'orange', 3: 'banana'}

# %%
dict={}
print(dict)
# Out:
# {}

# %%
Employee={"name":"vikasini","age":19,"salary":10000}
print(type(Employee))
print("name:%s"%Employee["name"])
print("age:%d"%Employee["age"])
print("salary:%d"%Employee["salary"])
# Out:
# <class 'dict'>
# name:vikasini
# age:19
# salary:10000

# %%
dict[0]='ram'
dict[3]='sam'
dict[4]='tom'
print(dict)
# Out:
# {0: 'ram', 3: 'sam', 'emp_ages': (10, 30, 55), 4: 'tom'}

# %%
dict['emp_ages']=10,30,55
print(dict)
# Out:
# {0: 'ram', 3: 'sam', 'emp_ages': (10, 30, 55), 4: 'tom'}

# %%
dict[2]='karan'
print(dict)
# Out:
# {0: 'ram', 3: 'sam', 'emp_ages': (10, 30, 55), 4: 'tom', 2: 'karan'}

# %%
Employee={"name":"vikasini","age":19,"salary":10000}
print(type(Employee))
print(Employee)
Employee["name"]=input("name:");
print(Employee)
del Employee["age"]
print(Employee)
# Out:
# <class 'dict'>
# {'name': 'vikasini', 'age': 19, 'salary': 10000}
# name:VARSHA
# {'name': 'VARSHA', 'age': 19, 'salary': 10000}
# {'name': 'VARSHA', 'salary': 10000}

# %%
dict={1:'apple',2:'orange',3:'banana'}
pop_key=dict.pop(2)
print(pop_key)
print(dict)
# Out:
# orange
# {1: 'apple', 3: 'banana'}

# %%
Employee={"name":"vikasini","age":19,"salary":10000}
for x in Employee:
  print(x)
# Out:
# name
# age
# salary

# %%
Employee={"name":"vikasini","age":19,"salary":10000}
for x in Employee:
  print(Employee[x])
# Out:
# vikasini
# 19
# 10000

# %%
Employee={"name":"vikasini","age":19,"salary":10000}
for x in Employee.values():
  print(x)
# Out:
# vikasini
# 19
# 10000

# %%
Employee={"name":"vikasini","age":19,"salary":10000}
for x in Employee.items():
  print(x)
# Out:
# ('name', 'vikasini')
# ('age', 19)
# ('salary', 10000)
