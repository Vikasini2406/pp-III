# %% [markdown]
# <a href="https://colab.research.google.com/github/Vikasini2406/pp-III/blob/main/tuple.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
t1=(2,3,4,5)
t2="apple"
print(t1)
print(t2)
# Out:
# (2, 3, 4, 5)
# apple

# %%
t1=(2,3,4,5)
t2="apple"
print(type(t1))
# Out:
# <class 'tuple'>

# %%
t1=(2,3,4,5)
t2="apple","orange",
print(t1+t2)
# Out:
# (2, 3, 4, 5, 'apple', 'orange')

# %%
t1=(2,3,4,5)
t=t1*4
print(t)
# Out:
# (2, 3, 4, 5, 2, 3, 4, 5, 2, 3, 4, 5, 2, 3, 4, 5)

# %%
t1=(2,3,4,5,13,14,8)
print(t1[0])
print(t1[1:5])
print(t1[1:7:2])
# Out:
# 2
# (3, 4, 5, 13)
# (3, 5, 14)

# %%
tuple=(1,7,9,0,3)
tuple[3]=10
print(tuple)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-720127378.py in <cell line: 0>()
#       1 tuple=(1,7,9,0,3)
# ----> 2 tuple[3]=10
#       3 print(tuple)
#
# TypeError: 'tuple' object does not support item assignment

# %%
t1=(2,3,4,5,13,14,8,2,2)
print(t1.count(2))
# Out:
# 3

# %%
t1=(1,3,2,3,4,5,13,14,8,2,2)
print(t1.index(2))
# Out:
# 2
