# %% [markdown]
# <a href="https://colab.research.google.com/github/Vikasini2406/pp-III/blob/main/set.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
days={"monday","tuesday","wednesday","thursday"}
print(days)
print(type(days))
# Out:
# {'monday', 'wednesday', 'tuesday', 'thursday'}
# <class 'set'>

# %%
days={"monday","tuesday","wednesday","thursday"}
for i in days:
  print(i)
# Out:
# monday
# wednesday
# tuesday
# thursday

# %%
days=set(["monday","tuesday","wednesday","thursday"])
print(days)
print(type(days))
# Out:
# {'monday', 'wednesday', 'tuesday', 'thursday'}
# <class 'set'>

# %%
set1={1,2,3,"apple",6,7}
print(type(set1))
# Out:
# <class 'set'>

# %%
set2={1,2,3,["Apple",9]}
print(type(set2))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-3449791224.py in <cell line: 0>()
# ----> 1 set2={1,2,3,["Apple",9]}
#       2 print(type(set2))
#
# TypeError: unhashable type: 'list'

# %%
set3={}
print(type(set3))
# Out:
# <class 'dict'>

# %%
set4=set()
print(type(set4))
# Out:
# <class 'set'>

# %%
set5={1,3,3,5,5,9,7}
print(set5)
# Out:
# {1, 3, 5, 7, 9}

# %%
days={"monday","tuesday","wednesday","thursday"}
print(days)
days.add("friday")
print(days)
days.update(["saturday","sunday"])
print(days)
days.discard("sunday")
print(days)
days.remove("monday")
print(days)
# Out:
# {'monday', 'wednesday', 'tuesday', 'thursday'}
# {'monday', 'friday', 'thursday', 'wednesday', 'tuesday'}
# {'monday', 'friday', 'sunday', 'thursday', 'wednesday', 'saturday', 'tuesday'}
# {'monday', 'friday', 'thursday', 'wednesday', 'saturday', 'tuesday'}
# {'friday', 'thursday', 'wednesday', 'saturday', 'tuesday'}

# %%
days={"monday","tuesday","wednesday","thursday"}
print(days)
days.pop()
print(days)
# Out:
# {'monday', 'wednesday', 'tuesday', 'thursday'}
# {'wednesday', 'tuesday', 'thursday'}

# %%
days1={"monday","tuesday","wednesday","thursday","sunday"}
days2={"friday","saturday","sunday"}
print(days1|days2)
# Out:
# {'monday', 'tuesday', 'wednesday', 'saturday', 'sunday', 'friday', 'thursday'}

# %%
days1={"monday","tuesday","wednesday","thursday"}
days2={"friday","saturday","sunday"}
print(days1.union(days2))
# Out:
# {'sunday', 'monday', 'wednesday', 'saturday', 'friday', 'tuesday', 'thursday'}

# %%
days1={"monday","tuesday","wednesday","thursday","sunday"}
days2={"friday","saturday","sunday"}
print(days1&days2)
# Out:
# {'sunday'}

# %%
days1={"monday","tuesday","wednesday","thursday"}
days2={"monday","friday","saturday","sunday"}
print(days1.intersection(days2))
# Out:
# {'monday'}

# %%
days1={"monday","tuesday","wednesday","thursday"}
days2={"monday","friday","saturday","sunday"}
print(days1.difference(days2))
# Out:
# {'wednesday', 'tuesday', 'thursday'}

# %%
days1={"monday","tuesday","wednesday","thursday"}
days2={"monday","friday","saturday","sunday"}
print(days1-days2)
# Out:
# {'wednesday', 'tuesday', 'thursday'}

# %%
days1={"monday","tuesday","wednesday","thursday","friday"}
days2={"monday","friday"}
print(days1>days2)
# Out:
# True

# %%
days1={"monday","tuesday","wednesday","thursday"}
days2={"monday","friday","saturday"}
print(days1<days2)
# Out:
# False

# %%
set=frozenset([1,2,3,4])
print(type(set))
set.add(9)
print(set)
# Out:
# <class 'frozenset'>
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipython-input-1444238489.py in <cell line: 0>()
#       1 set=frozenset([1,2,3,4])
#       2 print(type(set))
# ----> 3 set.add(9)
#       4 print(set)
#
# AttributeError: 'frozenset' object has no attribute 'add'
