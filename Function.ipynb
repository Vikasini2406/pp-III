# %% [markdown]
# <a href="https://colab.research.google.com/github/Vikasini2406/pp-III/blob/main/Function.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
def square(num):
  return num**2
object_=square(3)
print(object_)
# Out:
# 9

# %%
add = lambda num: num + 4
print( add(6) )
# Out:
# 10
