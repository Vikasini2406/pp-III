# %% [markdown]
# <a href="https://colab.research.google.com/github/Vikasini2406/pp-III/blob/main/list.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
list1=["apple","orange",4,5]
print(list1)
# Out:
# ['apple', 'orange', 4, 5]

# %%
list1=["apple","orange",4,5]
list2=["red","green",8,"blue"]
print(type(list1))
print(type(list2))
# Out:
# <class 'list'>
# <class 'list'>

# %%
a=["red","green",8,"blue"]
b=["red","green",4,"blue"]
a==b
# Out:
# False

# %%
list=[1,7,9,0,3]
print(list[2])
# Out:
# 9

# %%
list=[1,7,9,0,3]
print(list[-2])
print(list[0:])
print(list[3:1])
print(list[0:4])
print(list[1,4,2])
# Out:
# 0
# [1, 7, 9, 0, 3]
# []
# [1, 7, 9, 0]
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-2117086874.py in <cell line: 0>()
#       4 print(list[3:1])
#       5 print(list[0:4])
# ----> 6 print(list[1,4,1])
#
# TypeError: list indices must be integers or slices, not tuple

# %%
list=[1,7,9,0,3]
print(list[:2])
# Out:
# [1, 7]

# %%
list=[1,7,9,0,3]
list[3]=10
print(list)
# Out:
# [1, 7, 9, 10, 3]

# %%
list=[1,7,9,0,3]
list[1:3]=[10,20]
print(list)
# Out:
# [1, 10, 20, 0, 3]

# %%
list=[1,7,9,0,3]
list[3:1]=[10,20]
print(list)
# Out:
# [1, 7, 9, 10, 20, 0, 3]

# %%
l1=[1,2,3,4,5,6]
l=l1 * 3
print(l)
# Out:
# [1, 2, 3, 4, 5, 6, 1, 2, 3, 4, 5, 6, 1, 2, 3, 4, 5, 6]

# %%
list1=["apple","orange",4,5]
list2=["red","green",8,"blue"]
l=list1+list2
print(l)
# Out:
# ['apple', 'orange', 4, 5, 'red', 'green', 8, 'blue']

# %%
list2=["red","green",8,"blue"]
len(list2)
# Out:
# 4

# %%
list1=["apple","orange",4,5]
for i in list1:
  print(i)
# Out:
# apple
# orange
# 4
# 5

# %%
list1=["apple","orange",4,5]
for i in list1:
  print(i,end=" ")
# Out:
# apple orange 4 5

# %%
l1=[1,2,3,4,5,6]
max(l1)
# Out:
# 6

# %%
import copy
old_list = [[1, 2, 3], [4, 5, 6], [7, 8, 9]]
new_list = copy.copy(old_list)
print("Old list:", old_list)
print("New list:", new_list)
# Out:
# Old list: [[1, 2, 3], [4, 5, 6], [7, 8, 9]]
# New list: [[1, 2, 3], [4, 5, 6], [7, 8, 9]]

# %%
import copy
old_list = [[1, 2, 3], [4, 5, 6], [7, 8, 9]]
new_list = copy.copy(old_list)
#new_list.append([4, 4, 4])
old_list.append([4, 4, 4])
print("Old list:", old_list)
print("New list:", new_list)
# Out:
# Old list: [[1, 2, 3], [4, 5, 6], [7, 8, 9], [4, 4, 4]]
# New list: [[1, 2, 3], [4, 5, 6], [7, 8, 9]]

# %%
import copy
old_list = [[1, 2, 3], [4, 5, 6], [7, 8, 9]]
new_list = copy.copy(old_list)
old_list[1][1]='aa'
print("Old list:", old_list)
print("New list:", new_list)
# Out:
# Old list: [[1, 2, 3], [4, 'aa', 6], [7, 8, 9]]
# New list: [[1, 2, 3], [4, 'aa', 6], [7, 8, 9]]

# %%
import copy
old_list = [[1, 2, 3], [4, 5, 6], [7, 8, 9]]
new_list = copy.copy(old_list)
old_list[0][2]='aa'
print("Old list:", old_list)
print("New list:", new_list)
# Out:
# Old list: [[1, 2, 'aa'], [4, 5, 6], [7, 8, 9]]
# New list: [[1, 2, 'aa'], [4, 5, 6], [7, 8, 9]]

# %%
import copy
old_list = [[1, 2, 3], [4, 5, 6], [7, 8, 9]]
new_list = copy.deepcopy(old_list)
print("Old list:", old_list)
print("New list:", new_list)
# Out:
# Old list: [[1, 2, 3], [4, 5, 6], [7, 8, 9]]
# New list: [[1, 2, 3], [4, 5, 6], [7, 8, 9]]

# %%
import copy
old_list = [[1, 2, 3], [4, 5, 6], [7, 8, 9]]
new_list = copy.deepcopy(old_list)
new_list.append([4, 4])
#old_list.append([4, 4, 4])
print("Old list:", old_list)
print("New list:", new_list)
# Out:
# Old list: [[1, 2, 3], [4, 5, 6], [7, 8, 9]]
# New list: [[1, 2, 3], [4, 5, 6], [7, 8, 9], [4, 4]]

# %%
import copy
old_list = [[1, 2, 3], [4, 5, 6], [7, 8, 9]]
new_list = copy.deepcopy(old_list)
old_list[0][2]='aa'
print("Old list:", old_list)
print("New list:", new_list)
# Out:
# Old list: [[1, 2, 'aa'], [4, 5, 6], [7, 8, 9]]
# New list: [[1, 2, 3], [4, 5, 6], [7, 8, 9]]

# %%
import copy
old_list = [[1, 2, 3], [4, 5, 6], [7, 8, 9]]
new_list = copy.deepcopy(old_list)
old_list[2][0]='aa'
print("Old list:", old_list)
print("New list:", new_list)
# Out:
# Old list: [[1, 2, 3], [4, 5, 6], ['aa', 8, 9]]
# New list: [[1, 2, 3], [4, 5, 6], [7, 8, 9]]

# %%
import copy
old_list = [[1, 2, 3], [4, 5, 6], [7, 8, 9]]
new_list = copy.deepcopy(old_list)
old_list[1][2]=6
print("Old list:", old_list)
print("New list:", new_list)
# Out:
# Old list: [[1, 2, 3], [4, 5, 6], [7, 8, 9]]
# New list: [[1, 2, 3], [4, 5, 6], [7, 8, 9]]
