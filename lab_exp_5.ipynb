# %% [markdown]
# <a href="https://colab.research.google.com/github/Vikasini2406/pp-III/blob/main/lab_exp_5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import re
password=input("Enter password:")
pattern=r"^(?!\d)(?!.*(.)\1)(?=.*[a-z])(?=.*[A-Z])(?=.*\d)(?=.*[@#$%&!])[A-Za-z\d@#$%&!]{8,15}$"
if re.match(pattern,password):
 print("Valid Password")
else:
 print("Invalid Password")
# Out:
# Enter password:Ai@2026Pass
# Invalid Password

# %%
import re
pan=input("Enter PAN number:")
pattern=r"^[A-Z]{5}[0-9]{4}[A-Z]$"
if re.match(pattern,pan):
 print("Valid PAN Number")
else:
 print("Invalid PAN Number")
# Out:
# Enter PAN number:ABCDE1234F
# Valid PAN Number

# %%
import re
aadhaar = input("Enter Aadhaar Number: ")
pattern = r'^[2-9]\d{3}(\s?\d{4}){2}$'
if re.match(pattern, aadhaar):
    print("Valid Aadhaar Number")
else:
    print("Invalid Aadhaar Number")
# Out:
# Enter Aadhaar Number: 2345 6789 1234
# Valid Aadhaar Number

# %%
import re
logs = [
    "[INFO] 2026-01-12 10:15:30 - System started",
    "[ERROR] 2026-01-12 10:16:10 - Database connection failed",
    "[WARNING] 2026-01-12 10:17:45 - Memory usage high",
    "[ERROR] 2026-01-13 09:05:00 - Disk not found"
]
pattern = r'^\[ERROR\]\s(\d{4}-\d{2}-\d{2})\s\d{2}:\d{2}:\d{2}\s-\s(.+)$'
for log in logs:
    match = re.match(pattern, log)
    if match:
        date = match.group(1)
        message = match.group(2)
        print(f"{date} : {message}")
# Out:
# 2026-01-12 : Database connection failed
# 2026-01-13 : Disk not found
